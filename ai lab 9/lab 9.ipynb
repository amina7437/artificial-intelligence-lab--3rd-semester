# %% [markdown]
# ## **Data Loading and Reading:**

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\SYS\\Desktop\\ai lab 9\\student_burnout_dataset (1).csv")
data
# Out:
#       student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0              1   24    Male                  4.5          5.9
# 1              2   21    Male                  5.3          5.7
# 2              3   22    Male                  8.7          4.9
# 3              4   24    Male                  4.1          7.0
# 4              5   20  Female                  8.8          6.4
# ...          ...  ...     ...                  ...          ...
# 4995        4996   22  Female                  8.7          7.3
# 4996        4997   23    Male                  9.1          4.9
# 4997        4998   20  Female                  9.5          4.3
# 4998        4999   19  Female                  4.6          7.4
# 4999        5000   21    Male                  3.0          5.3
#
#       social_media_hours  attendance_percentage  assignment_completion_rate  \
# 0                    3.0                   86.5                        45.5
# ...

# %% [markdown]
# ## **Data Exploration:**

# %%
data.head()
# Out:
#    student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0           1   24    Male                  4.5          5.9
# 1           2   21    Male                  5.3          5.7
# 2           3   22    Male                  8.7          4.9
# 3           4   24    Male                  4.1          7.0
# 4           5   20  Female                  8.8          6.4
#
#    social_media_hours  attendance_percentage  assignment_completion_rate  \
# 0                 3.0                   86.5                        45.5
# 1                 4.5                   59.2                        43.6
# 2                 3.4                   67.3                        76.3
# 3                 0.5                   83.2                        98.0
# 4                 1.1                   74.1                        70.2
#
#    stress_level burnout_level  exam_score
# 0             6        Medium        42.1
# 1             1           Low        38.3
# ...

# %%
data.tail()
# Out:
#       student_id  age  gender  study_hours_per_day  sleep_hours  \
# 4995        4996   22  Female                  8.7          7.3
# 4996        4997   23    Male                  9.1          4.9
# 4997        4998   20  Female                  9.5          4.3
# 4998        4999   19  Female                  4.6          7.4
# 4999        5000   21    Male                  3.0          5.3
#
#       social_media_hours  attendance_percentage  assignment_completion_rate  \
# 4995                 5.3                   66.4                        97.1
# 4996                 0.3                   86.3                        84.9
# 4997                 1.8                   96.2                        41.2
# 4998                 2.7                   81.9                        64.1
# 4999                 1.0                   97.6                        55.4
#
#       stress_level burnout_level  exam_score
# 4995             7        Medium        50.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   student_id                  5000 non-null   int64
#  1   age                         5000 non-null   int64
#  2   gender                      5000 non-null   str
#  3   study_hours_per_day         5000 non-null   float64
#  4   sleep_hours                 5000 non-null   float64
#  5   social_media_hours          5000 non-null   float64
#  6   attendance_percentage       5000 non-null   float64
#  7   assignment_completion_rate  5000 non-null   float64
#  8   stress_level                5000 non-null   int64
#  9   burnout_level               5000 non-null   str
#  10  exam_score                  5000 non-null   float64
# dtypes: float64(6), int64(3), str(2)
# memory usage: 429.8 KB

# %%
print('rows: ', data.shape[0])
print('columns: ', data.shape[1])
# Out:
# rows:  5000
# columns:  11

# %%
data.isnull().sum()
# Out:
# student_id                    0
# age                           0
# gender                        0
# study_hours_per_day           0
# sleep_hours                   0
# social_media_hours            0
# attendance_percentage         0
# assignment_completion_rate    0
# stress_level                  0
# burnout_level                 0
# exam_score                    0
# dtype: int64

# %%
Dataset = data.fillna(data.mean)
Dataset = data.fillna(data.median)
Dataset = data.fillna(data.mode())
